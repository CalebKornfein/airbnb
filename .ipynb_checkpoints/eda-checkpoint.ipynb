# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import missingno as msn

pd.options.display.max_columns = 50
pd.options.display.max_rows = 100

# %%
# Load in data
df = pd.read_csv('data/initial_data/train.csv')

# Parse price
df['Price'] = df.apply(lambda x: int((x['Price'][1:]).split(".")[0].replace(",", "")), axis=1)

# Drop id as id is not useful for eda here
df = df.drop(columns=['id'], axis=1)

# %%
sum(df.isna().sum()) / (df.shape[0] * df.shape[1])

# %%
df.head(1)
# Out:
#    Decision Host_response_time Host_is_superhost Host_has_profile_pic  \
# 0         1     within an hour                 t                    t
#
#   Host_identity_verified  Neighbourhood Property_type        Room_type  \
# 0                      t          28806  Entire cabin  Entire home/apt
#
#    Accommodates Bathrooms_text  Bedrooms  Beds  Essentials  Cooking  Balcony  \
# 0             6         1 bath       3.0   3.0           5        5        1
#
#    Parking  Price  Number_of_reviews  Review_scores_rating Instant_bookable  \
# 0        1    164                 90                  4.93                t
#
#     Month
# 0  August

# %%
print(df.isna().sum())
# Out:
# Decision                    0
# Host_response_time        858
# Host_is_superhost          96
# Host_has_profile_pic       96
# Host_identity_verified     96
# Neighbourhood               0
# Property_type               0
# Room_type                   0
# Accommodates                0
# Bathrooms_text              0
# Bedrooms                  585
# Beds                       13
# Essentials                  0
# Cooking                     0
# Balcony                     0
# Parking                     0
# Price                       0
# Number_of_reviews           0
# Review_scores_rating      395
# Instant_bookable            0
# Month                       0
# dtype: int64

# %%
# Check summary statistics
df.describe()
# Out:
#                 id     Decision  Neighbourhood  Accommodates     Bedrooms  \
# count  7471.000000  7471.000000    7471.000000   7471.000000  6886.000000
# mean   3736.000000     0.633784   28793.443180      4.293267     1.837932
# std    2156.836263     0.481802      29.064001      2.762739     1.125600
# min       1.000000     0.000000   28704.000000      1.000000     1.000000
# 25%    1868.500000     0.000000   28801.000000      2.000000     1.000000
# 50%    3736.000000     1.000000   28804.000000      4.000000     1.000000
# 75%    5603.500000     1.000000   28806.000000      6.000000     2.000000
# max    7471.000000     1.000000   28806.000000     16.000000     9.000000
#
#               Beds   Essentials      Cooking      Balcony      Parking  \
# count  7458.000000  7471.000000  7471.000000  7471.000000  7471.000000
# mean      2.289890     4.723598     3.626824     0.632044     0.958506
# std       1.738629     0.617703     1.627228     0.482282     0.199443
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     5.000000     3.000000     0.000000     1.000000
# 50%       2.000000     5.000000     4.000000     1.000000     1.000000
# 75%       3.000000     5.000000     5.000000     1.000000     1.000000
# max      18.000000     5.000000     5.000000     1.000000     1.000000
#
#              Price  Number_of_reviews  Review_scores_rating
# count  7471.000000        7471.000000           7076.000000
# mean    184.457101          87.481997              4.881412
# std     174.435976         107.129371              0.238291
# min      19.000000           0.000000              0.000000
# 25%      93.000000          13.000000              4.850000
# 50%     137.000000          50.000000              4.930000
# 75%     223.000000         121.000000              4.990000
# max    3500.000000        1059.000000              5.000000

# %%
# Histogram:
df.hist(bins=50, figsize = (20,15))
plt.show()

# %%
#Check missingness:
fig = msn.matrix(df)
fig_copy = fig.get_figure()
fig_copy.savefig('missingness.png', bbox_inches='tight', facecolor='white')

missing_corr = msn.heatmap(df)
plt.show()

# %%
# Full Correlations

check correlations between all features
correlation_mat = df.corr()
plt.figure(figsize=(18,18))
top = correlation_mat.index
corr_plot = sns.heatmap(df[top].corr(), annot=True)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Correlations for Report Figure

x = df.drop(columns = ['Host_has_profile_pic', 'Property_type',
           'Bathrooms_text', 'Balcony', 'Parking', 'Neighbourhood', 'Cooking', 'Essentials', 
                       'Review_scores_rating'])

correlation_mat = x.corr()
plt.figure(figsize=(15,15))
top = correlation_mat.index
sns.set(font_scale=1.7)
corr_plot = sns.heatmap(df[top].corr(), annot=True, annot_kws={"fontsize":15})

plt.savefig('corr.png', facecolor='white')

# %%
# Using groupby, investigate correlations between different variables and decision

# Significant
print(df.groupby(['Room_type', 'Decision'], dropna=False).size())
# Significant
print(df.groupby(['Host_is_superhost', 'Decision'], dropna=False).size())
# Unsignificant
print(df.groupby(['Host_has_profile_pic', 'Decision'], dropna=False).size())
# Significant
print(df.groupby(['Host_identity_verified', 'Decision'], dropna=False).size())
# Significant, in general accomodating 8 or more had higher chance of being booked
print(df.groupby(['Accommodates', 'Decision'], dropna=False).size())
# Significant
print(df.groupby(['Host_response_time', 'Decision'], dropna=False).size())
# Not super significant
print(df.groupby(['Neighbourhood', 'Decision'], dropna=False).size())
# Not significant, lots of different property types, only entire condominium has lots of 1's, few 0's, entire bungalow
# Has more 0's than 1's
print(df.groupby(['Property_type', 'Decision'], dropna=False).size())
# Unsignificant
print(df.groupby(['Bathrooms_text', 'Decision'], dropna=False).size())
# Unsignificant
print(df.groupby(['Balcony', 'Decision'], dropna=False).size())
# Unsignificant
print(df.groupby(['Parking', 'Decision'], dropna=False).size())
# Significant
print(df.groupby(['Instant_bookable', 'Decision'], dropna=False).size())
# Significant
print(df.groupby(['Month', 'Decision'], dropna=False).size())
# Significant
print(df.groupby(['Bedrooms', 'Decision'], dropna=False).size())
print(df.groupby(['Beds', 'Decision'], dropna=False).size())
# Out:
# Room_type        Decision
# Entire home/apt  0           2333
#                  1           3899
# Hotel room       0              6
#                  1             60
# Private room     0            389
#                  1            760
# Shared room      0              8
#                  1             16
# dtype: int64
# Host_is_superhost  Decision
# f                  0            791
#                    1           1133
# t                  0           1909
#                    1           3542
# NaN                0             36
#                    1             60
# dtype: int64
# Host_has_profile_pic  Decision
# f                     0              4
#                       1              9
# t                     0           2696
#                       1           4666
# NaN                   0             36
#                       1             60
# dtype: int64
# Host_identity_verified  Decision
# f                       0            701
#                         1            992
# t                       0           1999
#                         1           3683
# NaN                     0             36
#                         1             60
# dtype: int64
# Accommodates  Decision
# 1             0             38
#               1             38
# 2             0           1025
#               1           1639
# 3             0            178
#               1            261
# 4             0            732
#               1           1245
# 5             0            136
#               1            173
# 6             0            324
#               1            645
# 7             0             72
#               1             81
# 8             0            119
#               1            291
# 9             0             11
#               1             15
# 10            0             38
#               1            121
# 11            0              9
#               1             38
# 12            0             26
#               1             61
# 13            0              2
#               1             10
# 14            0              3
#               1             41
# 15            1              5
# 16            0             23
#               1             71
# dtype: int64
# Host_response_time  Decision
# a few days or more  0             19
#                     1              5
# within a day        0            180
#                     1             82
# within a few hours  0            289
#                     1            220
# within an hour      0           1717
#                     1           4101
# NaN                 0            531
#                     1            327
# dtype: int64
# Neighbourhood  Decision
# 28704          0            169
#                1            260
# 28715          0             60
#                1            164
# 28732          0             65
#                1            138
# 28801          0            625
#                1           1152
# 28803          0            397
#                1            612
# 28804          0            359
#                1            581
# 28805          0            359
#                1            497
# 28806          0            702
#                1           1331
# dtype: int64
# Property_type                        Decision
# Bus                                  1            12
# Camper/RV                            0            11
#                                      1            21
# Campsite                             0             4
#                                      1            30
# Casa particular                      0             1
#                                      1             1
# Casa particular (Cuba)               0             3
#                                      1             1
# Entire apartment                     0           237
#                                      1           313
# Entire bungalow                      0           107
#                                      1            80
# Entire cabin                         0            84
#                                      1           132
# Entire chalet                        0             8
#                                      1            24
# Entire condominium                   0            43
#                                      1           149
# Entire condominium (condo)           0            32
#                                      1           160
# Entire cottage                       0           124
#                                      1           145
# Entire guest suite                   0           424
#                                      1           694
# Entire guesthouse                    0           117
#                                      1           129
# Entire house                         0           488
#                                      1           644
# Entire loft                          0            18
#                                      1            80
# Entire place                         0             4
#                                      1             4
# Entire rental unit                   0           178
#                                      1           358
# Entire residential home              0           344
#                                      1           738
# Entire townhouse                     0            54
#                                      1            83
# Entire villa                         0             2
#                                      1             2
# Farm stay                            0             5
#                                      1            11
# Private room                         1            20
# Private room in apartment            0             2
#                                      1            14
# Private room in bed and breakfast    0            21
#                                      1           125
# Private room in bungalow             0            34
#                                      1            43
# Private room in cabin                0             3
#                                      1             5
# Private room in camper/rv            0             4
#                                      1             4
# Private room in castle               1             4
# Private room in condominium          1             2
# Private room in condominium (condo)  0             2
# Private room in cottage              0             3
#                                      1             1
# Private room in farm stay            0             4
#                                      1             8
# Private room in guest suite          0            26
#                                      1            44
# Private room in guesthouse           0             5
#                                      1             3
# Private room in hostel               0             4
#                                      1             8
# Private room in house                0           144
#                                      1           211
# Private room in hut                  1             4
# Private room in rental unit          0             2
#                                      1            13
# Private room in residential home     0           123
#                                      1           208
# Private room in townhouse            0             4
#                                      1             4
# Private room in treehouse            1            16
# Room in bed and breakfast            0             2
#                                      1            54
# Room in boutique hotel               0             5
#                                      1            29
# Room in hotel                        0             7
# Shared room in apartment             0             2
# Shared room in hostel                1            16
# Shared room in house                 0             2
# Shared room in rental unit           0             2
# Shared room in residential home      0             2
# Shipping container                   1             4
# Tent                                 0             1
#                                      1             7
# Tiny house                           0            35
#                                      1            63
# Treehouse                            0             8
#                                      1             4
# Yurt                                 0             1
#                                      1            10
# dtype: int64
# Bathrooms_text     Decision
# 0 baths            0              7
#                    1              5
# 0 shared baths     0              4
# 1 bath             0           1512
#                    1           2507
# 1 private bath     0            198
#                    1            467
# 1 shared bath      0            108
#                    1            143
# 1.5 baths          0            130
#                    1            148
# 1.5 shared baths   0             11
#                    1             14
# 2 baths            0            484
#                    1            907
# 2 shared baths     0              9
#                    1             19
# 2.5 baths          0            117
#                    1            135
# 2.5 shared baths   0              4
#                    1             16
# 3 baths            0             79
#                    1            202
# 3.5 baths          0             27
#                    1             57
# 4 baths            0             21
#                    1             51
# 4.5 baths          0             10
#                    1             18
# 5 baths            0              2
#                    1             18
# 5.5 baths          0              4
# 6 baths            0              5
#                    1              7
# 6.5 baths          0              1
#                    1              5
# 7 baths            1              4
# 9 baths            0              3
#                    1              1
# Half-bath          1              7
# Private half-bath  1              4
# dtype: int64
# Balcony  Decision
# 0        0            965
#          1           1784
# 1        0           1771
#          1           2951
# dtype: int64
# Parking  Decision
# 0        0             82
#          1            228
# 1        0           2654
#          1           4507
# dtype: int64
# Instant_bookable  Decision
# f                 0           1516
#                   1           1566
# t                 0           1220
#                   1           3169
# dtype: int64
# Month      Decision
# August     0            569
#            1           1282
# July       0            780
#            1           1117
# June       0            784
#            1           1145
# September  0            603
#            1           1191
# dtype: int64
# Bedrooms  Decision
# 1.0       0           1295
#           1           2251
# 2.0       0            704
#           1           1102
# 3.0       0            364
#           1            613
# 4.0       0             99
#           1            268
# 5.0       0             29
#           1             68
# 6.0       0             13
#           1             44
# 7.0       0              6
#           1             14
# 8.0       0              6
#           1              6
# 9.0       0              3
#           1              1
# NaN       0            217
#           1            368
# dtype: int64
# Beds  Decision
# 0.0   0             53
#       1             86
# 1.0   0           1025
#       1           1766
# 2.0   0            852
#       1           1349
# 3.0   0            409
#       1            662
# 4.0   0            204
#       1            385
# 5.0   0             73
#       1            194
# 6.0   0             67
#       1            136
# 7.0   0             27
#       1             51
# 8.0   0              8
#       1             26
# 9.0   0              3
#       1             34
# 11.0  0              5
#       1             15
# 12.0  0              4
#       1              4
# 13.0  1              4
# 14.0  0              3
#       1              5
# 15.0  0              2
#       1              2
# 18.0  1              4
# NaN   0              1
#       1             12
# dtype: int64

# %%
# Check out the relationship between continuous variables and decision
for var in ['Accommodates','Bedrooms','Beds','Essentials', 'Cooking', 
            'Number_of_reviews', 'Review_scores_rating', 'Price']:
    fig, ax = plt.subplots(figsize = (5,3))
    ax = sns.boxplot(x="Decision", y=var, data=df)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (12,8))
ax = sns.scatterplot(x="Number_of_reviews", y='Review_scores_rating', data = df, hue="Decision")
plt.title("review score vs number of reviews")
plt.show()

fig, ax = plt.subplots(figsize = (12,8))
ax = sns.scatterplot(y="Price", x='Review_scores_rating', data = df, hue="Decision")
plt.title("Price vs number of reviews")
plt.show()

fig, ax = plt.subplots(figsize = (12,8))
ax = sns.scatterplot(y="Price", x='Accommodates', data = df, hue="Decision")
plt.title("Price vs number of reviews")
plt.show()

# %%
# segment the dataset by decision and again look at summary statistics
booked = df[df.Decision == 1]
unbooked = df[df.Decision == 0]
print(booked.describe())
print(unbooked.describe())
# Out:
#                 id  Decision  Neighbourhood  Accommodates     Bedrooms  \
# count  4735.000000    4735.0    4735.000000   4735.000000  4367.000000
# mean   3742.513622       1.0   28793.136008      4.460190     1.860545
# std    2140.680198       0.0      29.329871      2.926008     1.150800
# min       1.000000       1.0   28704.000000      1.000000     1.000000
# 25%    1918.500000       1.0   28801.000000      2.000000     1.000000
# 50%    3743.000000       1.0   28804.000000      4.000000     1.000000
# 75%    5562.500000       1.0   28806.000000      6.000000     2.000000
# max    7471.000000       1.0   28806.000000     16.000000     9.000000
#
#               Beds   Essentials      Cooking      Balcony      Parking  \
# count  4723.000000  4735.000000  4735.000000  4735.000000  4735.000000
# mean      2.346813     4.692291     3.611193     0.623231     0.951848
# std       1.824809     0.659125     1.603045     0.484627     0.214110
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     5.000000     3.000000     0.000000     1.000000
# 50%       2.000000     5.000000     4.000000     1.000000     1.000000
# 75%       3.000000     5.000000     5.000000     1.000000     1.000000
# max      18.000000     5.000000     5.000000     1.000000     1.000000
#
#        Number_of_reviews  Review_scores_rating
# count        4735.000000           4551.000000
# mean           92.909820              4.876216
# std           112.805219              0.192192
# min             0.000000              1.000000
# 25%            17.000000              4.840000
# 50%            53.000000              4.920000
# 75%           124.500000              4.980000
# max          1059.000000              5.000000
#                 id  Decision  Neighbourhood  Accommodates     Bedrooms  \
# count  2736.000000    2736.0    2736.000000   2736.000000  2519.000000
# mean   3724.727339       0.0   28793.974781      4.004386     1.798730
# std    2184.861721       0.0      28.595568      2.428197     1.079625
# min       3.000000       0.0   28704.000000      1.000000     1.000000
# 25%    1783.500000       0.0   28801.000000      2.000000     1.000000
# 50%    3730.000000       0.0   28804.000000      4.000000     1.000000
# 75%    5672.000000       0.0   28806.000000      5.000000     2.000000
# max    7463.000000       0.0   28806.000000     16.000000     9.000000
#
#               Beds   Essentials      Cooking      Balcony      Parking  \
# count  2735.000000  2736.000000  2736.000000  2736.000000  2736.000000
# mean      2.191590     4.777778     3.653874     0.647295     0.970029
# std       1.574254     0.534338     1.668201     0.477899     0.170538
# min       0.000000     1.000000     0.000000     0.000000     0.000000
# 25%       1.000000     5.000000     3.000000     0.000000     1.000000
# 50%       2.000000     5.000000     4.000000     1.000000     1.000000
# 75%       3.000000     5.000000     5.000000     1.000000     1.000000
# max      15.000000     5.000000     5.000000     1.000000     1.000000
#
#        Number_of_reviews  Review_scores_rating
# count        2736.000000           2525.000000
# mean           78.088450              4.890776
# std            95.817111              0.304044
# min             0.000000              0.000000
# 25%             9.000000              4.870000
# 50%            41.000000              4.950000
# 75%           112.000000              5.000000
# max           740.000000              5.000000

# %%
df.isna().sum()
# Out:
# id                          0
# Decision                    0
# Host_response_time        858
# Host_is_superhost          96
# Host_has_profile_pic       96
# Host_identity_verified     96
# Neighbourhood               0
# Property_type               0
# Room_type                   0
# Accommodates                0
# Bathrooms_text              0
# Bedrooms                  585
# Beds                       13
# Essentials                  0
# Cooking                     0
# Balcony                     0
# Parking                     0
# Price                       0
# Number_of_reviews           0
# Review_scores_rating      395
# Instant_bookable            0
# Month                       0
# dtype: int64
