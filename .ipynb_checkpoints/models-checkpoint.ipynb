# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from xgboost import cv

# %%
train = np.array(pd.read_csv('data/train.csv'))
train_labels = pd.read_csv('data/train_labels.csv')
train_id = train_labels['id']
train_decision = np.array(train_labels['Decision'])

test = np.array(pd.read_csv('data/test.csv'))
test_labels = pd.read_csv('data/test_labels.csv')

X_train, X_test, y_train, y_test = train_test_split(
    train, train_decision, test_size=0.2, random_state=0)

# %%
# APPROACH 1: RANDOM FOREST

# %%
param_grid = {
    'bootstrap': [True, False],
    'max_depth': [2, 4, 6, 10],
    'max_features': ['auto', 'log2'],
    'n_estimators': [100, 200]
}

score = 'accuracy'

# %%
rf = RandomForestClassifier(random_state=0)
clf = GridSearchCV(rf, param_grid, cv=5, n_jobs=2, scoring=score) 
clf.fit(X=train, y=train_decision)

# %%
print(f'Params: {clf.best_params_}')
print(f'Test: {clf.score(X_test, y_test)}')

test_submission = test_labels.copy()
test_submission['Decision'] = clf.predict(test)
test_submission.to_csv('submissions/rf_submission.csv', index=False)

# %%
# APPROACH 2: LOGISTIC REGRESSION

# %%
param_grid = {'penalty' : ['l1', 'l2'],
              'C' : np.logspace(-4, 4, 20),
              'solver' : ['liblinear']}

lr = GridSearchCV(LogisticRegression(random_state=0), param_grid=param_grid, scoring='accuracy', cv=5, n_jobs=2)
lr.fit(X=train, y=train_decision)

print(f'Params: {lr.best_params_}')
print(f'Test: {lr.best_score_}')

test_submission = test_labels.copy()
test_submission['Decision'] = clf.predict(test)
test_submission.to_csv('submissions/kr_submission.csv', index=False)
# Out:
# Params: {'C': 0.08858667904100823, 'penalty': 'l2', 'solver': 'liblinear'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4cdd9a43536f> in <module>
#       7
#       8 print(f'Params: {lr.best_params_}')
# ----> 9 print(f'Test: {lr.score(X_test, y_test)}')
#      10
#      11 test_submission = test_labels.copy()
#
# NameError: name 'X_test' is not defined

# %%
# APPROACH 3: XGBOOST

# %%
data = xgb.DMatrix(data=train,label=train_decision)

params = {
            'objective':'binary:logistic',
            'max_depth': 4,
            'alpha': 10,
            'learning_rate': 1.0,
            'n_estimators':100
}

xgb_cv = cv(dtrain=data, params=params, nfold=5,
                    num_boost_round=50, early_stopping_rounds=10, metrics="error", as_pandas=True, seed=7)
# Out:
# [15:05:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:05:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:05:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:05:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:05:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:576:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
xgb_cv
# Out:
#     train-error-mean  train-error-std  test-error-mean  test-error-std
# 0           0.298220         0.007351         0.314551        0.009786
# 1           0.292598         0.008560         0.309868        0.017960
# 2           0.281857         0.002948         0.303578        0.018159
# 3           0.275834         0.006433         0.300899        0.010686
# 4           0.268237         0.004108         0.297018        0.010245
# 5           0.264155         0.004725         0.293805        0.009690
# 6           0.260575         0.004497         0.293137        0.013240
# 7           0.255087         0.005523         0.288184        0.012771
# 8           0.250971         0.005657         0.288452        0.013352
# 9           0.246989         0.004190         0.285908        0.013982
# 10          0.243809         0.004495         0.284971        0.012171
# 11          0.241668         0.002936         0.282830        0.013305
# 12          0.237887         0.003825         0.279082        0.012967
# 13          0.235277         0.003250         0.280554        0.012317
# 14          0.233536         0.003372         0.279752        0.013519
# 15          0.230491         0.004138         0.278145        0.011588
# 16          0.227982         0.004892         0.275468        0.012181
# 17          0.226978         0.004375         0.275870        0.013187
# 18          0.223866         0.003934         0.277878        0.015633
# 19          0.223130         0.003428         0.276406        0.015830
# 20          0.220687         0.004690         0.271989        0.016867
# 21          0.219214         0.003668         0.273059        0.015681
# 22          0.218043         0.003332         0.273327        0.015115
# 23          0.215868         0.003580         0.274264        0.016173
# 24          0.214430         0.003936         0.273193        0.016001
# 25          0.212355         0.002921         0.271989        0.015287
# 26          0.211016         0.002604         0.272658        0.016675
# 27          0.208841         0.003616         0.270650        0.016524
# 28          0.207804         0.003375         0.271452        0.014675
# 29          0.206532         0.003339         0.271854        0.015479
# 30          0.205796         0.003080         0.270650        0.015503
# 31          0.204826         0.003853         0.270247        0.011541
# 32          0.203320         0.003136         0.268239        0.011786
# 33          0.202182         0.003829         0.267570        0.011775
# 34          0.201044         0.003557         0.267035        0.012311
# 35          0.200241         0.002745         0.266098        0.012509
# 36          0.198501         0.002958         0.266499        0.010058
# 37          0.198166         0.003649         0.267302        0.009819
# 38          0.197664         0.004040         0.265697        0.013456
# 39          0.196727         0.003399         0.265964        0.010333
# 40          0.195723         0.002391         0.263688        0.009146
# 41          0.194720         0.001906         0.261413        0.009815
# 42          0.194017         0.002182         0.263019        0.011033
# 43          0.193515         0.002074         0.263956        0.010654
# 44          0.193448         0.002813         0.263688        0.009787
# 45          0.192578         0.001969         0.261815        0.012101
# 46          0.191708         0.001727         0.262082        0.011035
# 47          0.192210         0.002054         0.263018        0.009362
# 48          0.192076         0.001967         0.263019        0.008396
# 49          0.191139         0.001756         0.262082        0.009204

# %%
xgb_clf = XGBClassifier(**params)
xgb_clf.fit(train, train_decision)
predictions = xgb_clf.predict(test)
# Out:
# [15:10:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
test_submission = test_labels.copy()
test_submission['Decision'] = predictions
test_submission.to_csv('submissions/xgb_submission.csv', index=False)
